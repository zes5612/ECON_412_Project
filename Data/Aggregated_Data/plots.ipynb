# %%
import polars as pl
import matplotlib.pyplot as plt
import os 

# print(os.getcwd()): already in Aggregated_Data folder
df = pl.read_csv("Sector_compounded_yearly_returns.csv")

df
# Out:
# shape: (110, 3)
# ┌──────┬────────────────────────┬───────────────────┐
# │ Year ┆ Sector                 ┆ Compounded Return │
# │ ---  ┆ ---                    ┆ ---               │
# │ i64  ┆ str                    ┆ f64               │
# ╞══════╪════════════════════════╪═══════════════════╡
# │ 2015 ┆ Communication Services ┆ 16.762076         │
# │ 2015 ┆ Consumer Discretionary ┆ 34.205187         │
# │ 2015 ┆ Consumer Staples       ┆ 45.171659         │
# │ 2015 ┆ Energy                 ┆ -0.997629         │
# │ 2015 ┆ Financials             ┆ 5.403933          │
# │ …    ┆ …                      ┆ …                 │
# │ 2024 ┆ Industrials            ┆ 180521.498008     │
# │ 2024 ┆ Information Technology ┆ 9111.359934       │
# │ 2024 ┆ Materials              ┆ -0.086141         │
# │ 2024 ┆ Real Estate            ┆ 8.908623          │
# │ 2024 ┆ Utilities              ┆ 885.446346        │
# └──────┴────────────────────────┴───────────────────┘

# %%
df_partitiions = df.partition_by("Sector")
df_partitiions
# Out:
# [shape: (10, 3)
#  ┌──────┬────────────────────────┬───────────────────┐
#  │ Year ┆ Sector                 ┆ Compounded Return │
#  │ ---  ┆ ---                    ┆ ---               │
#  │ i64  ┆ str                    ┆ f64               │
#  ╞══════╪════════════════════════╪═══════════════════╡
#  │ 2015 ┆ Communication Services ┆ 16.762076         │
#  │ 2016 ┆ Communication Services ┆ 14.419799         │
#  │ 2017 ┆ Communication Services ┆ 206.339666        │
#  │ 2018 ┆ Communication Services ┆ 1.30939           │
#  │ 2019 ┆ Communication Services ┆ 453.973831        │
#  │ 2020 ┆ Communication Services ┆ 79.494973         │
#  │ 2021 ┆ Communication Services ┆ 8.866626          │
#  │ 2022 ┆ Communication Services ┆ -0.999886         │
#  │ 2023 ┆ Communication Services ┆ 198.781753        │
#  │ 2024 ┆ Communication Services ┆ 123.026126        │
#  └──────┴────────────────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬────────────────────────┬───────────────────┐
#  │ Year ┆ Sector                 ┆ Compounded Return │
#  │ ---  ┆ ---                    ┆ ---               │
#  │ i64  ┆ str                    ┆ f64               │
#  ╞══════╪════════════════════════╪═══════════════════╡
#  │ 2015 ┆ Consumer Discretionary ┆ 34.205187         │
#  │ 2016 ┆ Consumer Discretionary ┆ 28.853881         │
#  │ 2017 ┆ Consumer Discretionary ┆ 269683.556921     │
#  │ 2018 ┆ Consumer Discretionary ┆ -0.947789         │
#  │ 2019 ┆ Consumer Discretionary ┆ 1.4548e6          │
#  │ 2020 ┆ Consumer Discretionary ┆ 1024.217372       │
#  │ 2021 ┆ Consumer Discretionary ┆ 283195.897422     │
#  │ 2022 ┆ Consumer Discretionary ┆ -1.0              │
#  │ 2023 ┆ Consumer Discretionary ┆ 1.1764e6          │
#  │ 2024 ┆ Consumer Discretionary ┆ 1177.718913       │
#  └──────┴────────────────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬──────────────────┬───────────────────┐
#  │ Year ┆ Sector           ┆ Compounded Return │
#  │ ---  ┆ ---              ┆ ---               │
#  │ i64  ┆ str              ┆ f64               │
#  ╞══════╪══════════════════╪═══════════════════╡
#  │ 2015 ┆ Consumer Staples ┆ 45.171659         │
#  │ 2016 ┆ Consumer Staples ┆ 9.02887           │
#  │ 2017 ┆ Consumer Staples ┆ 53.839989         │
#  │ 2018 ┆ Consumer Staples ┆ -0.941147         │
#  │ 2019 ┆ Consumer Staples ┆ 3753.40112        │
#  │ 2020 ┆ Consumer Staples ┆ 36.960826         │
#  │ 2021 ┆ Consumer Staples ┆ 157.076636        │
#  │ 2022 ┆ Consumer Staples ┆ 0.893845          │
#  │ 2023 ┆ Consumer Staples ┆ -0.886014         │
#  │ 2024 ┆ Consumer Staples ┆ -0.221463         │
#  └──────┴──────────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬────────┬───────────────────┐
#  │ Year ┆ Sector ┆ Compounded Return │
#  │ ---  ┆ ---    ┆ ---               │
#  │ i64  ┆ str    ┆ f64               │
#  ╞══════╪════════╪═══════════════════╡
#  │ 2015 ┆ Energy ┆ -0.997629         │
#  │ 2016 ┆ Energy ┆ 1171.039857       │
#  │ 2017 ┆ Energy ┆ 0.78235           │
#  │ 2018 ┆ Energy ┆ -0.992079         │
#  │ 2019 ┆ Energy ┆ 4.65232           │
#  │ 2020 ┆ Energy ┆ -0.999517         │
#  │ 2021 ┆ Energy ┆ 26313.670279      │
#  │ 2022 ┆ Energy ┆ 23377.079883      │
#  │ 2023 ┆ Energy ┆ 0.342649          │
#  │ 2024 ┆ Energy ┆ 7.493471          │
#  └──────┴────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬────────────┬───────────────────┐
#  │ Year ┆ Sector     ┆ Compounded Return │
#  │ ---  ┆ ---        ┆ ---               │
#  │ i64  ┆ str        ┆ f64               │
#  ╞══════╪════════════╪═══════════════════╡
#  │ 2015 ┆ Financials ┆ 5.403933          │
#  │ 2016 ┆ Financials ┆ 251357.170525     │
#  │ 2017 ┆ Financials ┆ 2.9333e7          │
#  │ 2018 ┆ Financials ┆ -0.999211         │
#  │ 2019 ┆ Financials ┆ 7.7818e9          │
#  │ 2020 ┆ Financials ┆ 66.601656         │
#  │ 2021 ┆ Financials ┆ 2.4716e7          │
#  │ 2022 ┆ Financials ┆ -0.999968         │
#  │ 2023 ┆ Financials ┆ 58337.756736      │
#  │ 2024 ┆ Financials ┆ 2.4973e7          │
#  └──────┴────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬─────────────┬───────────────────┐
#  │ Year ┆ Sector      ┆ Compounded Return │
#  │ ---  ┆ ---         ┆ ---               │
#  │ i64  ┆ str         ┆ f64               │
#  ╞══════╪═════════════╪═══════════════════╡
#  │ 2015 ┆ Health Care ┆ 231.98145         │
#  │ 2016 ┆ Health Care ┆ 1.472027          │
#  │ 2017 ┆ Health Care ┆ 812565.139087     │
#  │ 2018 ┆ Health Care ┆ 25.181489         │
#  │ 2019 ┆ Health Care ┆ 1.0890e6          │
#  │ 2020 ┆ Health Care ┆ 166742.163608     │
#  │ 2021 ┆ Health Care ┆ 749436.4387       │
#  │ 2022 ┆ Health Care ┆ -0.994517         │
#  │ 2023 ┆ Health Care ┆ 4.393377          │
#  │ 2024 ┆ Health Care ┆ -0.894009         │
#  └──────┴─────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬─────────────┬───────────────────┐
#  │ Year ┆ Sector      ┆ Compounded Return │
#  │ ---  ┆ ---         ┆ ---               │
#  │ i64  ┆ str         ┆ f64               │
#  ╞══════╪═════════════╪═══════════════════╡
#  │ 2015 ┆ Industrials ┆ -0.816023         │
#  │ 2016 ┆ Industrials ┆ 7.9003e6          │
#  │ 2017 ┆ Industrials ┆ 1.0442e8          │
#  │ 2018 ┆ Industrials ┆ -0.999604         │
#  │ 2019 ┆ Industrials ┆ 1.1504e10         │
#  │ 2020 ┆ Industrials ┆ 1.5106e6          │
#  │ 2021 ┆ Industrials ┆ 1.2845e7          │
#  │ 2022 ┆ Industrials ┆ -0.99988          │
#  │ 2023 ┆ Industrials ┆ 2.0525e7          │
#  │ 2024 ┆ Industrials ┆ 180521.498008     │
#  └──────┴─────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬────────────────────────┬───────────────────┐
#  │ Year ┆ Sector                 ┆ Compounded Return │
#  │ ---  ┆ ---                    ┆ ---               │
#  │ i64  ┆ str                    ┆ f64               │
#  ╞══════╪════════════════════════╪═══════════════════╡
#  │ 2015 ┆ Information Technology ┆ 0.162171          │
#  │ 2016 ┆ Information Technology ┆ 30150.723946      │
#  │ 2017 ┆ Information Technology ┆ 5.0438e8          │
#  │ 2018 ┆ Information Technology ┆ 0.967433          │
#  │ 2019 ┆ Information Technology ┆ 5.3062e10         │
#  │ 2020 ┆ Information Technology ┆ 6.2288e10         │
#  │ 2021 ┆ Information Technology ┆ 5.8932e8          │
#  │ 2022 ┆ Information Technology ┆ -1.0              │
#  │ 2023 ┆ Information Technology ┆ 9.7005e10         │
#  │ 2024 ┆ Information Technology ┆ 9111.359934       │
#  └──────┴────────────────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬───────────┬───────────────────┐
#  │ Year ┆ Sector    ┆ Compounded Return │
#  │ ---  ┆ ---       ┆ ---               │
#  │ i64  ┆ str       ┆ f64               │
#  ╞══════╪═══════════╪═══════════════════╡
#  │ 2015 ┆ Materials ┆ -0.855888         │
#  │ 2016 ┆ Materials ┆ 183.372992        │
#  │ 2017 ┆ Materials ┆ 209.405413        │
#  │ 2018 ┆ Materials ┆ -0.980578         │
#  │ 2019 ┆ Materials ┆ 204.290257        │
#  │ 2020 ┆ Materials ┆ 104.493863        │
#  │ 2021 ┆ Materials ┆ 1157.077159       │
#  │ 2022 ┆ Materials ┆ -0.952888         │
#  │ 2023 ┆ Materials ┆ 9.075482          │
#  │ 2024 ┆ Materials ┆ -0.086141         │
#  └──────┴───────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬─────────────┬───────────────────┐
#  │ Year ┆ Sector      ┆ Compounded Return │
#  │ ---  ┆ ---         ┆ ---               │
#  │ i64  ┆ str         ┆ f64               │
#  ╞══════╪═════════════╪═══════════════════╡
#  │ 2015 ┆ Real Estate ┆ 3.614             │
#  │ 2016 ┆ Real Estate ┆ 4.639382          │
#  │ 2017 ┆ Real Estate ┆ 38.184079         │
#  │ 2018 ┆ Real Estate ┆ -0.546657         │
#  │ 2019 ┆ Real Estate ┆ 3449.258842       │
#  │ 2020 ┆ Real Estate ┆ -0.766599         │
#  │ 2021 ┆ Real Estate ┆ 134439.22462      │
#  │ 2022 ┆ Real Estate ┆ -0.999806         │
#  │ 2023 ┆ Real Estate ┆ 24.933064         │
#  │ 2024 ┆ Real Estate ┆ 8.908623          │
#  └──────┴─────────────┴───────────────────┘,
#  shape: (10, 3)
#  ┌──────┬───────────┬───────────────────┐
#  │ Year ┆ Sector    ┆ Compounded Return │
#  │ ---  ┆ ---       ┆ ---               │
#  │ i64  ┆ str       ┆ f64               │
#  ╞══════╪═══════════╪═══════════════════╡
#  │ 2015 ┆ Utilities ┆ -0.849852         │
#  │ 2016 ┆ Utilities ┆ 168.764147        │
#  │ 2017 ┆ Utilities ┆ 55.968494         │
#  │ 2018 ┆ Utilities ┆ 3.971822          │
#  │ 2019 ┆ Utilities ┆ 299.882417        │
#  │ 2020 ┆ Utilities ┆ -0.70247          │
#  │ 2021 ┆ Utilities ┆ 88.429259         │
#  │ 2022 ┆ Utilities ┆ 2.929042          │
#  │ 2023 ┆ Utilities ┆ -0.464156         │
#  │ 2024 ┆ Utilities ┆ 885.446346        │
#  └──────┴───────────┴───────────────────┘]

# %%
# number of partitions/ Sectors
len(df_partitiions)
# Out:
# 11

# %%
# list of sectors
sectors = list(df["Sector"].unique())
sectors
# Out:
# ['Consumer Staples',
#  'Materials',
#  'Information Technology',
#  'Financials',
#  'Consumer Discretionary',
#  'Communication Services',
#  'Industrials',
#  'Energy',
#  'Health Care',
#  'Utilities',
#  'Real Estate']

# %%
colors = [
    "blue",
    "orange",
    "mediumseagreen",
    "red",
    "purple",
    "brown",
    "fuchsia",
    "gray",
    "olive",
    "aqua",
    "gold"
]
colors
# Out:
# ['blue',
#  'orange',
#  'mediumseagreen',
#  'red',
#  'purple',
#  'brown',
#  'fuchsia',
#  'gray',
#  'olive',
#  'aqua',
#  'gold']

# %%
color_map = dict(zip(sectors, colors))
fix, ax = plt.subplots(figsize=(18, 6))

for df_part in df_partitiions:
    sector = df_part["Sector"][0]
    ax.plot(
        df_part["Year"], df_part["Compounded Return"],
        label=sector
        )
    
ax.grid(True, axis="y")
ax.legend(title="Sector")
    
ax.set(xlabel="Year",
        ylabel="Compounded Yearly Returns",
        title="Compunded Yearly Returns of the\nS&P 500 by Sector, 10 Years")
    
plt.show()

# %% [markdown]
# We can see how this needs to be broken up into two plots

# %%
df.sort("Compounded Return")
# Out:
# shape: (110, 3)
# ┌──────┬────────────────────────┬───────────────────┐
# │ Year ┆ Sector                 ┆ Compounded Return │
# │ ---  ┆ ---                    ┆ ---               │
# │ i64  ┆ str                    ┆ f64               │
# ╞══════╪════════════════════════╪═══════════════════╡
# │ 2022 ┆ Information Technology ┆ -1.0              │
# │ 2022 ┆ Consumer Discretionary ┆ -1.0              │
# │ 2022 ┆ Financials             ┆ -0.999968         │
# │ 2022 ┆ Communication Services ┆ -0.999886         │
# │ 2022 ┆ Industrials            ┆ -0.99988          │
# │ …    ┆ …                      ┆ …                 │
# │ 2019 ┆ Financials             ┆ 7.7818e9          │
# │ 2019 ┆ Industrials            ┆ 1.1504e10         │
# │ 2019 ┆ Information Technology ┆ 5.3062e10         │
# │ 2020 ┆ Information Technology ┆ 6.2288e10         │
# │ 2023 ┆ Information Technology ┆ 9.7005e10         │
# └──────┴────────────────────────┴───────────────────┘

# %% [markdown]
# TODO:
# - Find average
# - Find median
# - Determine which measure is the better value to use to break up the plot
