# %%
import polars as pl 
# import os

# Sample ticker
data_path = "Data/Master_Data/MMM.csv"

df = pl.read_csv(data_path)

df.head()
# Out:
# shape: (5, 9)
# ┌────────────┬───────────┬───────────┬───────────┬───┬─────────┬────────┬─────────────┬────────────┐
# │ Date       ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Volume  ┆ Ticker ┆ Sector      ┆ Sub-Indust │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---     ┆ ---    ┆ ---         ┆ ry         │
# │ str        ┆ f64       ┆ f64       ┆ f64       ┆   ┆ i64     ┆ str    ┆ str         ┆ ---        │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ str        │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═════════╪════════╪═════════════╪════════════╡
# │ 2015-01-02 ┆ 96.108543 ┆ 96.706063 ┆ 95.329408 ┆ … ┆ 2531214 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-05 ┆ 93.94104  ┆ 95.86251  ┆ 93.777022 ┆ … ┆ 4416708 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-06 ┆ 92.939308 ┆ 94.53272  ┆ 92.406222 ┆ … ┆ 4224272 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-07 ┆ 93.612976 ┆ 93.894166 ┆ 93.109172 ┆ … ┆ 3685235 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-08 ┆ 95.856644 ┆ 95.891795 ┆ 94.03477  ┆ … ┆ 3758908 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# └────────────┴───────────┴───────────┴───────────┴───┴─────────┴────────┴─────────────┴────────────┘

# %% [markdown]
# Number of trading days

# %%
df.shape
# Out:
# (2516, 9)

# %% [markdown]
# Compute daily returns as percent change

# %%
df = df.with_columns(pl.col("Close").pct_change().fill_null(0).alias("Daily Return"))
df.head(10)
# Out:
# shape: (10, 10)
# ┌────────────┬───────────┬───────────┬───────────┬───┬────────┬────────────┬───────────┬───────────┐
# │ Date       ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Ticker ┆ Sector     ┆ Sub-Indus ┆ Daily     │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---    ┆ ---        ┆ try       ┆ Return    │
# │ str        ┆ f64       ┆ f64       ┆ f64       ┆   ┆ str    ┆ str        ┆ ---       ┆ ---       │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ str       ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪════════╪════════════╪═══════════╪═══════════╡
# │ 2015-01-02 ┆ 96.108543 ┆ 96.706063 ┆ 95.329408 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ 0.0       │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-05 ┆ 93.94104  ┆ 95.86251  ┆ 93.777022 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.022553 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-06 ┆ 92.939308 ┆ 94.53272  ┆ 92.406222 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.010663 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-07 ┆ 93.612976 ┆ 93.894166 ┆ 93.109172 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ 0.007248  │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-08 ┆ 95.856644 ┆ 95.891795 ┆ 94.03477  ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ 0.023967  │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-09 ┆ 94.679169 ┆ 96.073411 ┆ 94.47414  ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.012284 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-12 ┆ 94.163651 ┆ 95.130239 ┆ 93.741866 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.005445 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-13 ┆ 94.093361 ┆ 96.296021 ┆ 93.407962 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.000746 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-14 ┆ 93.636429 ┆ 94.040638 ┆ 92.851435 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.004856 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-15 ┆ 93.530968 ┆ 94.573717 ┆ 93.36108  ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.001126 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# Combine all ticker CSVs

# %%
import glob

files = glob.glob("Data/Master_Data/*.csv")
dfs = [pl.read_csv(file) for file in files]

master_df = pl.concat(dfs)

master_df = master_df.with_columns(pl.col("Date").str.strptime(pl.Date, "%Y-%m-%d"))


master_df.head(20)
# Out:
# shape: (20, 9)
# ┌────────────┬───────────┬───────────┬───────────┬───┬─────────┬────────┬────────┬─────────────────┐
# │ Date       ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Volume  ┆ Ticker ┆ Sector ┆ Sub-Industry    │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---     ┆ ---    ┆ ---    ┆ ---             │
# │ date       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ i64     ┆ str    ┆ str    ┆ str             │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═════════╪════════╪════════╪═════════════════╡
# │ 2015-01-02 ┆ 37.120953 ┆ 37.807361 ┆ 36.94706  ┆ … ┆ 1529200 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-05 ┆ 36.425388 ┆ 37.029427 ┆ 36.333869 ┆ … ┆ 2041800 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-06 ┆ 35.857956 ┆ 36.626733 ┆ 35.711522 ┆ … ┆ 2080600 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-07 ┆ 36.333874 ┆ 36.434548 ┆ 35.958637 ┆ … ┆ 3359700 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-08 ┆ 37.422966 ┆ 37.505335 ┆ 36.773167 ┆ … ┆ 2116300 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …       ┆ …      ┆ …      ┆ …               │
# │ 2015-01-26 ┆ 35.830505 ┆ 35.848807 ┆ 35.208162 ┆ … ┆ 1510900 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-27 ┆ 35.46442  ┆ 35.922026 ┆ 35.308836 ┆ … ┆ 1703500 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-28 ┆ 34.778008 ┆ 35.738978 ┆ 34.741398 ┆ … ┆ 2033500 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-29 ┆ 35.198997 ┆ 35.208152 ┆ 34.494285 ┆ … ┆ 2330000 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-30 ┆ 34.567516 ┆ 35.070882 ┆ 34.512602 ┆ … ┆ 3054300 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# └────────────┴───────────┴───────────┴───────────┴───┴─────────┴────────┴────────┴─────────────────┘

# %%
master_df.shape
# Out:
# (1225438, 9)

# %% [markdown]
# Daily Returns per Ticker

# %%
master_df = master_df.with_columns(pl.col("Close").pct_change().over("Ticker").fill_null(0).alias("Daily Return"))
#master_df.filter(pl.col(""))

# %% [markdown]
# Aggregated Average Returns and Volatility by Sector

# %%
# NOT what we need; just curious
sector_summary = master_df.group_by("Sector").agg([
    pl.col("Daily Return").mean().alias("Sector Avg Daily Return"),
    pl.col("Daily Return").std().alias("Sector Volatility")
]).drop_nulls()

sector_summary
# Out:
# shape: (11, 3)
# ┌────────────────────────┬─────────────────────────┬───────────────────┐
# │ Sector                 ┆ Sector Avg Daily Return ┆ Sector Volatility │
# │ ---                    ┆ ---                     ┆ ---               │
# │ str                    ┆ f64                     ┆ f64               │
# ╞════════════════════════╪═════════════════════════╪═══════════════════╡
# │ Industrials            ┆ 0.000716                ┆ 0.019279          │
# │ Information Technology ┆ 0.000984                ┆ 0.023962          │
# │ Energy                 ┆ 0.000615                ┆ 0.026709          │
# │ Communication Services ┆ 0.000689                ┆ 0.022192          │
# │ Materials              ┆ 0.000555                ┆ 0.021194          │
# │ …                      ┆ …                       ┆ …                 │
# │ Consumer Staples       ┆ 0.000382                ┆ 0.015836          │
# │ Consumer Discretionary ┆ 0.000727                ┆ 0.023612          │
# │ Real Estate            ┆ 0.000446                ┆ 0.018037          │
# │ Utilities              ┆ 0.000477                ┆ 0.016811          │
# │ Health Care            ┆ 0.00058                 ┆ 0.019437          │
# └────────────────────────┴─────────────────────────┴───────────────────┘

# %%
sector_summary.shape
# Out:
# (11, 3)

# %% [markdown]
# Aggregated Average Returns and Volatility by Sub-Industry

# %%
# NOT what we need; just curious
industry_summary = master_df.group_by("Sub-Industry").agg([
    pl.col("Daily Return").mean().alias("Sub-Industry Avg Daily Return"),
    pl.col("Daily Return").std().alias("Sub-Industry Volatility")
]).drop_nulls()

# %% [markdown]
# Extract 'year' from master_df

# %%
master_df = master_df.with_columns(
    pl.col("Date").dt.year().alias("Year")  # extract year
)

master_df.head()
# Out:
# shape: (5, 11)
# ┌────────────┬───────────┬───────────┬───────────┬───┬────────┬──────────────┬──────────────┬──────┐
# │ Date       ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Sector ┆ Sub-Industry ┆ Daily Return ┆ Year │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---    ┆ ---          ┆ ---          ┆ ---  │
# │ date       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ str    ┆ str          ┆ f64          ┆ i32  │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪════════╪══════════════╪══════════════╪══════╡
# │ 2015-01-02 ┆ 37.120953 ┆ 37.807361 ┆ 36.94706  ┆ … ┆ Health ┆ Life         ┆ 0.0          ┆ 2015 │
# │            ┆           ┆           ┆           ┆   ┆ Care   ┆ Sciences     ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Tools &      ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Services     ┆              ┆      │
# │ 2015-01-05 ┆ 36.425388 ┆ 37.029427 ┆ 36.333869 ┆ … ┆ Health ┆ Life         ┆ -0.018738    ┆ 2015 │
# │            ┆           ┆           ┆           ┆   ┆ Care   ┆ Sciences     ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Tools &      ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Services     ┆              ┆      │
# │ 2015-01-06 ┆ 35.857956 ┆ 36.626733 ┆ 35.711522 ┆ … ┆ Health ┆ Life         ┆ -0.015578    ┆ 2015 │
# │            ┆           ┆           ┆           ┆   ┆ Care   ┆ Sciences     ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Tools &      ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Services     ┆              ┆      │
# │ 2015-01-07 ┆ 36.333874 ┆ 36.434548 ┆ 35.958637 ┆ … ┆ Health ┆ Life         ┆ 0.013272     ┆ 2015 │
# │            ┆           ┆           ┆           ┆   ┆ Care   ┆ Sciences     ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Tools &      ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Services     ┆              ┆      │
# │ 2015-01-08 ┆ 37.422966 ┆ 37.505335 ┆ 36.773167 ┆ … ┆ Health ┆ Life         ┆ 0.029975     ┆ 2015 │
# │            ┆           ┆           ┆           ┆   ┆ Care   ┆ Sciences     ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Tools &      ┆              ┆      │
# │            ┆           ┆           ┆           ┆   ┆        ┆ Services     ┆              ┆      │
# └────────────┴───────────┴───────────┴───────────┴───┴────────┴──────────────┴──────────────┴──────┘

# %% [markdown]
# Yearly Compounded Return by Sector

# %%
daily_sector_returns = master_df.group_by(["Date", "Sector"]).agg(
    pl.col("Daily Return").mean().alias("Sector Daily Return")
)
daily_sector_returns = daily_sector_returns.with_columns(
    pl.col("Date").dt.year().alias("Year") 
)


yearly_sector_returns = daily_sector_returns.group_by(["Year", "Sector"]).agg([
    ((1 + pl.col("Sector Daily Return")).cum_prod().last() - 1).alias("Compounded Return")
]).drop_nulls().sort(["Year", "Sector"])


print(yearly_sector_returns)

yearly_sector_returns.write_csv("Sector_compounded_yearly_returns.csv")
# Out:
# shape: (110, 3)
# ┌──────┬────────────────────────┬───────────────────┐
# │ Year ┆ Sector                 ┆ Compounded Return │
# │ ---  ┆ ---                    ┆ ---               │
# │ i32  ┆ str                    ┆ f64               │
# ╞══════╪════════════════════════╪═══════════════════╡
# │ 2015 ┆ Communication Services ┆ 0.179921          │
# │ 2015 ┆ Consumer Discretionary ┆ 0.106293          │
# │ 2015 ┆ Consumer Staples       ┆ 0.134425          │
# │ 2015 ┆ Energy                 ┆ -0.226913         │
# │ 2015 ┆ Financials             ┆ 0.038498          │
# │ …    ┆ …                      ┆ …                 │
# │ 2024 ┆ Industrials            ┆ 0.200633          │
# │ 2024 ┆ Information Technology ┆ 0.214675          │
# │ 2024 ┆ Materials              ┆ 0.026011          │
# │ 2024 ┆ Real Estate            ┆ 0.090798          │
# │ 2024 ┆ Utilities              ┆ 0.267421          │
# └──────┴────────────────────────┴───────────────────┘

# %% [markdown]
# Daily Arithemic Return by Sector

# %%
sector_daily_returns = (
    master_df
    .group_by(["Date", "Sector"])
    .agg(
        pl.col("Daily Return").mean().alias("Sector Daily Return")
    )
)

sector_daily_returns
# Out:
# shape: (30_192, 3)
# ┌────────────┬────────────────────────┬─────────────────────┐
# │ Date       ┆ Sector                 ┆ Sector Daily Return │
# │ ---        ┆ ---                    ┆ ---                 │
# │ date       ┆ str                    ┆ f64                 │
# ╞════════════╪════════════════════════╪═════════════════════╡
# │ 2016-04-08 ┆ Financials             ┆ 0.002351            │
# │ 2018-09-13 ┆ Industrials            ┆ 0.004056            │
# │ 2016-03-23 ┆ Utilities              ┆ 0.002488            │
# │ 2024-01-31 ┆ Consumer Discretionary ┆ -0.014913           │
# │ 2017-07-05 ┆ Financials             ┆ 0.00177             │
# │ …          ┆ …                      ┆ …                   │
# │ 2016-03-15 ┆ Consumer Staples       ┆ 0.001014            │
# │ 2016-05-03 ┆ Communication Services ┆ -0.014812           │
# │ 2022-03-30 ┆ Materials              ┆ -0.003673           │
# │ 2020-06-01 ┆ Utilities              ┆ 0.010862            │
# │ 2017-09-08 ┆ Financials             ┆ 0.012363            │
# └────────────┴────────────────────────┴─────────────────────┘

# %%
sector_daily_returns = sector_daily_returns.with_columns(
    pl.col("Date").dt.year().alias("Year")
)

sector_daily_returns
# Out:
# shape: (30_192, 4)
# ┌────────────┬────────────────────────┬─────────────────────┬──────┐
# │ Date       ┆ Sector                 ┆ Sector Daily Return ┆ Year │
# │ ---        ┆ ---                    ┆ ---                 ┆ ---  │
# │ date       ┆ str                    ┆ f64                 ┆ i32  │
# ╞════════════╪════════════════════════╪═════════════════════╪══════╡
# │ 2016-04-08 ┆ Financials             ┆ 0.002351            ┆ 2016 │
# │ 2018-09-13 ┆ Industrials            ┆ 0.004056            ┆ 2018 │
# │ 2016-03-23 ┆ Utilities              ┆ 0.002488            ┆ 2016 │
# │ 2024-01-31 ┆ Consumer Discretionary ┆ -0.014913           ┆ 2024 │
# │ 2017-07-05 ┆ Financials             ┆ 0.00177             ┆ 2017 │
# │ …          ┆ …                      ┆ …                   ┆ …    │
# │ 2016-03-15 ┆ Consumer Staples       ┆ 0.001014            ┆ 2016 │
# │ 2016-05-03 ┆ Communication Services ┆ -0.014812           ┆ 2016 │
# │ 2022-03-30 ┆ Materials              ┆ -0.003673           ┆ 2022 │
# │ 2020-06-01 ┆ Utilities              ┆ 0.010862            ┆ 2020 │
# │ 2017-09-08 ┆ Financials             ┆ 0.012363            ┆ 2017 │
# └────────────┴────────────────────────┴─────────────────────┴──────┘

# %% [markdown]
# Annualized Sector Volatility

# %%
annual_sector_volatility = (
    sector_daily_returns
    .group_by(["Year", "Sector"])
    .agg(
        (pl.col("Sector Daily Return").std() * (252 ** 0.5)).alias("Annual Volatility")
    )
) # ~252 trading days

annual_sector_volatility
# Out:
# shape: (120, 3)
# ┌──────┬────────────────────────┬───────────────────┐
# │ Year ┆ Sector                 ┆ Annual Volatility │
# │ ---  ┆ ---                    ┆ ---               │
# │ i32  ┆ str                    ┆ f64               │
# ╞══════╪════════════════════════╪═══════════════════╡
# │ 2024 ┆ Real Estate            ┆ 0.160767          │
# │ 2024 ┆ Industrials            ┆ 0.141895          │
# │ 2020 ┆ Consumer Staples       ┆ 0.265958          │
# │ 2023 ┆ Information Technology ┆ 0.197951          │
# │ 2022 ┆ Energy                 ┆ 0.373388          │
# │ …    ┆ …                      ┆ …                 │
# │ 2023 ┆ Materials              ┆ 0.175758          │
# │ 2024 ┆ Information Technology ┆ 0.205311          │
# │ 2020 ┆ Utilities              ┆ 0.390985          │
# │ 2018 ┆ Utilities              ┆ 0.151351          │
# │ 2020 ┆ Energy                 ┆ 0.674149          │
# └──────┴────────────────────────┴───────────────────┘
