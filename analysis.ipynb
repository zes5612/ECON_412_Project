# %%
import polars as pl 
# import os

# Sample ticker
data_path = "Data/Master_Data/MMM.csv"

df = pl.read_csv(data_path)

df.head()
# Out:
# shape: (5, 9)
# ┌────────────┬───────────┬───────────┬───────────┬───┬─────────┬────────┬─────────────┬────────────┐
# │ Date       ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Volume  ┆ Ticker ┆ Sector      ┆ Sub-Indust │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---     ┆ ---    ┆ ---         ┆ ry         │
# │ str        ┆ f64       ┆ f64       ┆ f64       ┆   ┆ i64     ┆ str    ┆ str         ┆ ---        │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ str        │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═════════╪════════╪═════════════╪════════════╡
# │ 2015-01-02 ┆ 96.108574 ┆ 96.706094 ┆ 95.329438 ┆ … ┆ 2531214 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-05 ┆ 93.941017 ┆ 95.862487 ┆ 93.776999 ┆ … ┆ 4416708 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-06 ┆ 92.939262 ┆ 94.532673 ┆ 92.406176 ┆ … ┆ 4224272 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-07 ┆ 93.612999 ┆ 93.894189 ┆ 93.109195 ┆ … ┆ 3685235 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# │ 2015-01-08 ┆ 95.856674 ┆ 95.891826 ┆ 94.034799 ┆ … ┆ 3758908 ┆ MMM    ┆ Industrials ┆ Industrial │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ Conglomera │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆             ┆ tes        │
# └────────────┴───────────┴───────────┴───────────┴───┴─────────┴────────┴─────────────┴────────────┘

# %% [markdown]
# Number of trading days

# %%
df.shape
# Out:
# (2516, 9)

# %% [markdown]
# Compute daily returns as percent change

# %%
df = df.with_columns(pl.col("Close").pct_change().fill_null(0).alias("Daily Return"))
df.head(10)
# Out:
# shape: (10, 10)
# ┌────────────┬───────────┬───────────┬───────────┬───┬────────┬────────────┬───────────┬───────────┐
# │ Date       ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Ticker ┆ Sector     ┆ Sub-Indus ┆ Daily     │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---    ┆ ---        ┆ try       ┆ Return    │
# │ str        ┆ f64       ┆ f64       ┆ f64       ┆   ┆ str    ┆ str        ┆ ---       ┆ ---       │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ str       ┆ f64       │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪════════╪════════════╪═══════════╪═══════════╡
# │ 2015-01-02 ┆ 96.108574 ┆ 96.706094 ┆ 95.329438 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ 0.0       │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-05 ┆ 93.941017 ┆ 95.862487 ┆ 93.776999 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.022553 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-06 ┆ 92.939262 ┆ 94.532673 ┆ 92.406176 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.010664 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-07 ┆ 93.612999 ┆ 93.894189 ┆ 93.109195 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ 0.007249  │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-08 ┆ 95.856674 ┆ 95.891826 ┆ 94.034799 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ 0.023968  │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-09 ┆ 94.679169 ┆ 96.073411 ┆ 94.47414  ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.012284 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-12 ┆ 94.163651 ┆ 95.130239 ┆ 93.741866 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.005445 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-13 ┆ 94.093369 ┆ 96.296028 ┆ 93.40797  ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.000746 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-14 ┆ 93.636398 ┆ 94.040607 ┆ 92.851404 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.004857 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# │ 2015-01-15 ┆ 93.530952 ┆ 94.573702 ┆ 93.361065 ┆ … ┆ MMM    ┆ Industrial ┆ Industria ┆ -0.001126 │
# │            ┆           ┆           ┆           ┆   ┆        ┆ s          ┆ l Conglom ┆           │
# │            ┆           ┆           ┆           ┆   ┆        ┆            ┆ erates    ┆           │
# └────────────┴───────────┴───────────┴───────────┴───┴────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# Combine all ticker CSVs

# %%
import glob

files = glob.glob("Data/Master_Data/*.csv")
dfs = [pl.read_csv(file) for file in files]
master_df = pl.concat(dfs)
master_df = master_df.with_columns(pl.col("Date").str.strptime(pl.Date, "%Y-%m-%d"))


master_df.head(20)
# Out:
# shape: (20, 9)
# ┌────────────┬───────────┬───────────┬───────────┬───┬─────────┬────────┬────────┬─────────────────┐
# │ Date       ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Volume  ┆ Ticker ┆ Sector ┆ Sub-Industry    │
# │ ---        ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---     ┆ ---    ┆ ---    ┆ ---             │
# │ str        ┆ f64       ┆ f64       ┆ f64       ┆   ┆ i64     ┆ str    ┆ str    ┆ str             │
# ╞════════════╪═══════════╪═══════════╪═══════════╪═══╪═════════╪════════╪════════╪═════════════════╡
# │ 2015-01-02 ┆ 37.120949 ┆ 37.807357 ┆ 36.947057 ┆ … ┆ 1529200 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-05 ┆ 36.425385 ┆ 37.029423 ┆ 36.333865 ┆ … ┆ 2041800 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-06 ┆ 35.857952 ┆ 36.626729 ┆ 35.711519 ┆ … ┆ 2080600 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-07 ┆ 36.33387  ┆ 36.434544 ┆ 35.958634 ┆ … ┆ 3359700 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-08 ┆ 37.422958 ┆ 37.505327 ┆ 36.77316  ┆ … ┆ 2116300 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ …          ┆ …         ┆ …         ┆ …         ┆ … ┆ …       ┆ …      ┆ …      ┆ …               │
# │ 2015-01-26 ┆ 35.830502 ┆ 35.848803 ┆ 35.208158 ┆ … ┆ 1510900 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-27 ┆ 35.464409 ┆ 35.922014 ┆ 35.308825 ┆ … ┆ 1703500 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-28 ┆ 34.778    ┆ 35.73897  ┆ 34.741391 ┆ … ┆ 2033500 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-29 ┆ 35.199005 ┆ 35.208159 ┆ 34.494292 ┆ … ┆ 2330000 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# │ 2015-01-30 ┆ 34.56752  ┆ 35.070885 ┆ 34.512606 ┆ … ┆ 3054300 ┆ A      ┆ Health ┆ Life Sciences   │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆ Care   ┆ Tools &         │
# │            ┆           ┆           ┆           ┆   ┆         ┆        ┆        ┆ Services        │
# └────────────┴───────────┴───────────┴───────────┴───┴─────────┴────────┴────────┴─────────────────┘

# %%
master_df.shape
# Out:
# (1222922, 9)

# %% [markdown]
# Daily Returns

# %%
master_df = master_df.with_columns(pl.col("Close").pct_change().over("Ticker").fill_null(0).alias("Daily Return"))
master_df.head(10)
# Out:
# shape: (10, 10)
# ┌─────────────┬───────────┬───────────┬───────────┬───┬────────┬────────┬─────────────┬────────────┐
# │ Date        ┆ Close     ┆ High      ┆ Low       ┆ … ┆ Ticker ┆ Sector ┆ Sub-Industr ┆ Daily      │
# │ ---         ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---    ┆ ---    ┆ y           ┆ Return     │
# │ str         ┆ f64       ┆ f64       ┆ f64       ┆   ┆ str    ┆ str    ┆ ---         ┆ ---        │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ str         ┆ f64        │
# ╞═════════════╪═══════════╪═══════════╪═══════════╪═══╪════════╪════════╪═════════════╪════════════╡
# │ 2015-01-02  ┆ 37.120949 ┆ 37.807357 ┆ 36.947057 ┆ … ┆ A      ┆ Health ┆ Life        ┆ 0.0        │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-05  ┆ 36.425385 ┆ 37.029423 ┆ 36.333865 ┆ … ┆ A      ┆ Health ┆ Life        ┆ -0.018738  │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-06  ┆ 35.857952 ┆ 36.626729 ┆ 35.711519 ┆ … ┆ A      ┆ Health ┆ Life        ┆ -0.015578  │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-07  ┆ 36.33387  ┆ 36.434544 ┆ 35.958634 ┆ … ┆ A      ┆ Health ┆ Life        ┆ 0.013272   │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-08  ┆ 37.422958 ┆ 37.505327 ┆ 36.77316  ┆ … ┆ A      ┆ Health ┆ Life        ┆ 0.029974   │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-09  ┆ 37.148403 ┆ 37.523639 ┆ 36.873841 ┆ … ┆ A      ┆ Health ┆ Life        ┆ -0.007337  │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-12  ┆ 36.709106 ┆ 37.267386 ┆ 36.562673 ┆ … ┆ A      ┆ Health ┆ Life        ┆ -0.011825  │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-13  ┆ 36.19659  ┆ 37.249084 ┆ 35.995246 ┆ … ┆ A      ┆ Health ┆ Life        ┆ -0.013962  │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-14  ┆ 35.748142 ┆ 35.784748 ┆ 34.970211 ┆ … ┆ A      ┆ Health ┆ Life        ┆ -0.012389  │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# │ 2015-01-15  ┆ 34.787159 ┆ 36.068455 ┆ 34.768858 ┆ … ┆ A      ┆ Health ┆ Life        ┆ -0.026882  │
# │             ┆           ┆           ┆           ┆   ┆        ┆ Care   ┆ Sciences    ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Tools &     ┆            │
# │             ┆           ┆           ┆           ┆   ┆        ┆        ┆ Services    ┆            │
# └─────────────┴───────────┴───────────┴───────────┴───┴────────┴────────┴─────────────┴────────────┘

# %% [markdown]
# Aggregated Average Returns and Volatility by Sector

# %%
sector_summary = master_df.group_by("Sector").agg([
    pl.col("Daily Return").mean().alias("Sector Avg Daily Return"),
    pl.col("Daily Return").std().alias("Sector Volatility")
]).drop_nulls()

sector_summary
# Out:
# shape: (11, 3)
# ┌────────────────────────┬─────────────────────────┬───────────────────┐
# │ Sector                 ┆ Sector Avg Daily Return ┆ Sector Volatility │
# │ ---                    ┆ ---                     ┆ ---               │
# │ str                    ┆ f64                     ┆ f64               │
# ╞════════════════════════╪═════════════════════════╪═══════════════════╡
# │ Industrials            ┆ 0.000716                ┆ 0.019279          │
# │ Utilities              ┆ 0.000477                ┆ 0.016811          │
# │ Consumer Discretionary ┆ 0.000727                ┆ 0.023612          │
# │ Energy                 ┆ 0.000615                ┆ 0.026709          │
# │ Communication Services ┆ 0.000689                ┆ 0.022192          │
# │ …                      ┆ …                       ┆ …                 │
# │ Materials              ┆ 0.000555                ┆ 0.021194          │
# │ Financials             ┆ 0.000663                ┆ 0.019445          │
# │ Consumer Staples       ┆ 0.000382                ┆ 0.015836          │
# │ Information Technology ┆ 0.000988                ┆ 0.023999          │
# │ Health Care            ┆ 0.00058                 ┆ 0.019437          │
# └────────────────────────┴─────────────────────────┴───────────────────┘

# %%
sector_summary.shape
# Out:
# (11, 3)

# %% [markdown]
# Aggregated Average Returns and Volatility by Sub-Industry

# %%
industry_summary = master_df.group_by("Sub-Industry").agg([
    pl.col("Daily Return").mean().alias("Sub-Industry Avg Daily Return"),
    pl.col("Daily Return").std().alias("Sub-Industry Volatility")
]).drop_nulls()

industry_summary
# Out:
# shape: (127, 3)
# ┌─────────────────────────────────┬───────────────────────────────┬─────────────────────────┐
# │ Sub-Industry                    ┆ Sub-Industry Avg Daily Return ┆ Sub-Industry Volatility │
# │ ---                             ┆ ---                           ┆ ---                     │
# │ str                             ┆ f64                           ┆ f64                     │
# ╞═════════════════════════════════╪═══════════════════════════════╪═════════════════════════╡
# │ Advertising                     ┆ 0.00105                       ┆ 0.027729                │
# │ Internet Services & Infrastruc… ┆ 0.000725                      ┆ 0.019633                │
# │ Diversified Support Services    ┆ 0.001015                      ┆ 0.016872                │
# │ Footwear                        ┆ 0.001356                      ┆ 0.02526                 │
# │ Pharmaceuticals                 ┆ 0.000403                      ┆ 0.016554                │
# │ …                               ┆ …                             ┆ …                       │
# │ Property & Casualty Insurance   ┆ 0.000699                      ┆ 0.016069                │
# │ Health Care Distributors        ┆ 0.000472                      ┆ 0.017326                │
# │ Application Software            ┆ 0.001094                      ┆ 0.022954                │
# │ Trading Companies & Distributo… ┆ 0.000912                      ┆ 0.022449                │
# │ Oil & Gas Equipment & Services  ┆ 0.000289                      ┆ 0.026102                │
# └─────────────────────────────────┴───────────────────────────────┴─────────────────────────┘

# %% [markdown]
# Extract 'year' from master_df

# %%
master_df = master_df.with_columns(
    pl.col("Date").dt.year().alias("Year")  # extract year
)

master_df.head()
# Out:
# Schema([('Date', String),
#         ('Close', Float64),
#         ('High', Float64),
#         ('Low', Float64),
#         ('Open', Float64),
#         ('Volume', Int64),
#         ('Ticker', String),
#         ('Sector', String),
#         ('Sub-Industry', String),
#         ('Daily Return', Float64)])
